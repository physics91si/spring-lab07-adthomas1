# %% [markdown]
# # Lab 07

# %%
from skimage import data, io
import numpy as np
from matplotlib import pyplot as plt
import time

# %% [markdown]
# ## Part 1

# %%
starry = io.imread("starry.jpg")
print(type(starry))
print(starry.shape)
io.imshow(starry)
# Out:
# <class 'numpy.ndarray'>
# (764, 1145, 3)

# %%
red = np.copy(starry)
green = np.copy(starry)
blue = np.copy(starry)
red[:,:,1] = 0
red[:,:,2] = 0
green[:,:,0] = 0
green[:,:,2] = 0 
blue[:,:,0] = 0
blue[:,:,1] = 0
f, (r,g,b) = plt.subplots (1,3,figsize = (30,50))
r.set_title("Red")
g.set_title("Green")
b.set_title("Blue")
r.imshow(red)
#plt.show(r)
g.imshow(green)
#plt.show(g)
b.imshow(blue)
plt.show()

# %% [markdown]
# ## Part 2

# %%
from math import sqrt
from skimage.feature import blob_log, blob_doh
from skimage.color import rgb2gray

# %%
# Here is the image of the Hubble Deep Field. 
image = data.hubble_deep_field()[0:500, 0:500]
f, (original,gray) = plt.subplots (1,2)
original.set_title("Original")
gray.set_title("Gray")
original.imshow(image)
grayim = rgb2gray(image)
gray.imshow(grayim)
#Convert the image to grayscale and display next to the original.

# %%
io.imshow(grayim, cmap  = plt.cm.gray)

# %%
start_time = time.clock()
resultlog = blob_log(grayim)
timelog = time.clock () - start_time
print("LoG = ",timelog, "seconds")
start_time2 = time.clock()
resultdoh = blob_doh(grayim)
timedoh = time.clock () - start_time2
print("DoH = ",timedoh, "seconds")
f2, (log,doh) = plt.subplots (1,2)
log.set_title("LoG")
doh.set_title("Doh")
log.imshow(image)
doh.imshow(image)
for i in resultlog:
    circle = plt.Circle((i[1],i[0]),i[2],color = 'yellow', fill = False)
    log.add_patch(circle)
for j in resultdoh:
    circle = plt.Circle((j[1],j[0]),j[2],color = 'yellow', fill = False)
    doh.add_patch(circle)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """
# ...
